# %%
last_values = {"STK000:CONTROL_X": 0.0,
                            "STK000:CONTROL_Y": 0.0,
                            "QDK001:CONTROL_X": 0.0,
                            "QDK001:CONTROL_Y": 0.0,
                            "STK001:CONTROL_X": 0.0,
                            "STK001:CONTROL_Y": 0.0}

# %%
beamOff_parameters = last_values.copy()

# %%
beamOff_parameters
# Out:
# {'STK000:CONTROL_X': 0.0,
#  'STK000:CONTROL_Y': 0.0,
#  'QDK001:CONTROL_X': 0.0,
#  'QDK001:CONTROL_Y': 0.0,
#  'STK001:CONTROL_X': 0.0,
#  'STK001:CONTROL_Y': 0.0}

# %%
beamOff_parameters['STK000:CONTROL_X'] = 500

# %%
beamOff_parameters
# Out:
# {'STK000:CONTROL_X': 500,
#  'STK000:CONTROL_Y': 0.0,
#  'QDK001:CONTROL_X': 0.0,
#  'QDK001:CONTROL_Y': 0.0,
#  'STK001:CONTROL_X': 0.0,
#  'STK001:CONTROL_Y': 0.0}

# %%
new_rate = 0
value = 14

# %%
rate = value -- new_rate

# %%
rate
# Out:
# 14
